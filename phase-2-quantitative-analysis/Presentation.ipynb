# %% [markdown]
# # Part 1: Analyze 33 projects using cppstats

# %% [markdown]
# ## Definitions
#
# - version 0: old version of project to be analyzed. Is 2008/2009 version, or something close to that.
# - version 1: new version of project to be analyzed. Is 2020/2021 version, or something close to that.
# - metric diff: differentiating a metric between version 0 and 1. E.g., discipline diff.

# %% [markdown]
# ## Structure and Algorithms
#
# This project use [cppstats](https://github.com/clhunsen/cppstats), and the cppstats project use [srcML](https://www.srcml.org/). The idea is simple: for an target project, transform all files in xml using srcML, and get the ifdef tags. After that, analyze the structure of this collected data.
#
# For each project, download all the code to a local directory and run cppstats. The cppstats tool will generate a csv file with the metrics.

# %% [markdown]
# ## Projects
#
# Project | Old version | Link old version | New version | Link new version
# --------|-------------|-------------|-----|-------
# [Apache](https://httpd.apache.org)| 2.2.11 | [github](https://github.com/apache/httpd/tree/2.2.11) | 2.4.46 | [github](https://github.com/apache/httpd/tree/2.4.46)
# [Cherokee](http://cherokee-project.com/) | 0.99.11 | [mirror](https://mirror.aarnet.edu.au/pub/cherokee/0.99/0.99.11/cherokee-0.99.11.tar.gz) or [drive link](https://drive.google.com/drive/folders/1vEBwLPyEwY1s-4BzErST9JRpLCEa84fM?usp=sharing) | 1.2.104 | [github](https://github.com/cherokee/webserver/tree/v1.2.104)
# [Berkeley DB](https://www.oracle.com/database/technologies/related/berkeleydb.html) | 4.7.25 | [mirror](http://ftpmirror.your.org/pub/misc/Berkeley-DB/) or [drive](https://drive.google.com/drive/u/2/folders/1vEBwLPyEwY1s-4BzErST9JRpLCEa84fM) | 18.1 | [oracle](https://www.oracle.com/database/technologies/related/berkeleydb-downloads.html) or [drive](https://drive.google.com/drive/u/2/folders/1vEBwLPyEwY1s-4BzErST9JRpLCEa84fM)
# [Clamav](https://www.clamav.net/) | 0.94.2 | [github](https://github.com/Cisco-Talos/clamav-devel/tree/clamav-0.94.2) | 0.104 | [github](https://github.com/Cisco-Talos/clamav-devel/tree/dev/0.104)
# [cpython](https://www.python.org/) | 2.6.1 | [github](https://github.com/python/cpython/tree/v2.6.1) | 3.9.3 | [github](https://github.com/python/cpython/tree/v3.9.3)
# [Dia](https://wiki.gnome.org/action/show/Apps/Dia?action=show&redirect=Dia) | 0.96.1 | [github](https://github.com/GNOME/dia/tree/DIA_0_96_1) | 0.97.2 | [github](https://github.com/GNOME/dia/tree/DIA_0_97_2)
# [Emacs](www.gnu.org/software/emacs/) | 22.3 | [github](https://github.com/emacs-mirror/emacs/tree/emacs-22.3) | 27.1.91 | [github](https://github.com/emacs-mirror/emacs/tree/emacs-27.1.91)
# [freebsd](https://www.freebsd.org) | 7.1 | [github](https://github.com/freebsd/freebsd-src/tree/release/7.1.0) | 12.2 | [github](https://github.com/freebsd/freebsd-src/tree/release/12.2.0)
# [gcc](https://gcc.gnu.org/) | 4.3.3 | [github](https://github.com/gcc-mirror/gcc/tree/releases/gcc-4.3.3) | 10.2.0 | [github](https://github.com/gcc-mirror/gcc/tree/releases/gcc-10.2.0)
# [ghostscript](https://www.ghostscript.com/) | 8.62.0 | [github](https://github.com/ArtifexSoftware/ghostpdl/tree/ghostscript-8.62) | 9.52 | [github](https://github.com/ArtifexSoftware/ghostpdl/tree/ghostscript-9.52)
# [gimp](https://www.gimp.org/) | 2.6.4 | [github](https://github.com/GNOME/gimp/tree/GIMP_2_6_4) | 2.10.24 | [github](https://github.com/GNOME/gimp/tree/GIMP_2_10_24)
# [glibc](https://www.gnu.org/software/libc/) | 2.9 | [github](https://github.com/bminor/glibc/tree/glibc-2.9) | 2.33 | [github](https://github.com/bminor/glibc/tree/glibc-2.33)
# [gnumeric](http://www.gnumeric.org/) | 1.9.5 | [github](https://github.com/GNOME/gnumeric/tree/GNUMERIC_1_9_5) | 1.12.49 | [github](https://github.com/GNOME/gnumeric/tree/GNUMERIC_1_12_49)
# [gnuplot](http://www.gnuplot.info/) | 4.2.5 | [github](https://github.com/gnuplot/gnuplot/tree/4.2.5) | 5.4.1 | [github](https://github.com/gnuplot/gnuplot/tree/5.4.1)
# [irssi](https://irssi.org/) | 0.8.13 | [github](https://github.com/irssi/irssi/tree/0.8.13) | 1.2.2 | [github](https://github.com/irssi/irssi/tree/1.2.2)
# [libxml2](http://www.xmlsoft.org/) | 2.7.3 | [github](https://github.com/GNOME/libxml2/tree/LIBXML2.7.3) | 2.9.10 | [github](https://github.com/GNOME/libxml2/tree/v2.9.10)
# [lighttpd](https://www.lighttpd.net/) | 1.4.22 | [github](https://github.com/lighttpd/lighttpd1.4/tree/lighttpd-1.4.22) | 1.4.59 | [github](https://github.com/lighttpd/lighttpd1.4/tree/lighttpd-1.4.59)
# [linux](https://www.linux.org/) | 2.6.28.7 | [github](https://github.com/torvalds/linux/tree/v2.6.28-rc7) | 5.12.5 | [github](https://github.com/torvalds/linux/tree/v5.12-rc5)
# [lynx](https://lynx.invisible-island.net/) | 2.8.6 | [archive](https://ftp.isc.org/lynx/current/lynx2.8.6rel.5.tar.Z) | 2.8.8 | [archive](https://ftp.isc.org/lynx/current/lynx2.8.8dev.8.tar.Z)
# [openldap](https://www.openldap.org/) | 2.4.16 | [github](https://github.com/openldap/openldap/tree/OPENLDAP_REL_ENG_2_4_16) | 2.4.58 | [github](https://github.com/openldap/openldap/tree/OPENLDAP_REL_ENG_2_4_58)
# [openvpn](https://openvpn.net/) | 2.1-rc1 | [github](https://github.com/OpenVPN/openvpn/tree/v2.1_rc1) | 2.5.1 | [github](https://github.com/OpenVPN/openvpn/tree/v2.5.1)
# [parrot](http://parrot.org/) | 0.9.1 | [github](https://github.com/parrot-mirror/parrot/tree/RELEASE_0_9_1) | 2.9.1 | [github](https://github.com/parrot-mirror/parrot/tree/RELEASE_2_9_1)
# [php](https://www.php.net/) | 5.2.8 | [github](https://github.com/php/php-src/tree/php-5.2.8) | 8.0.4-rc1 | [github](https://github.com/php/php-src/tree/php-8.0.4RC1)
# [postgresql](https://www.postgresql.org/) | 8.4-beta2 | [github](https://github.com/postgres/postgres/tree/REL8_4_BETA2) | 13.2 | [github](https://github.com/postgres/postgres/tree/REL_13_2)
# [privoxy](http://www.privoxy.org/) | 3.0.12 | [github](https://github.com/unisx/privoxy/tree/privoxy-3.0.12-stable) | 3.0.24 | [github](https://github.com/unisx/privoxy/tree/privoxy-3.0.24-stable)
# [sendmail](https://www.proofpoint.com/us/products/email-protection/open-source-email-solution) | 8.14.2 | [ftp](ftp://ftp.athena.pads.ufrj.br/pub/sendmail/sendmail.8.14.2.tar.gz) | 8.16.1 | [ftp](ftp://ftp.sendmail.org/pub/sendmail/sendmail.8.16.1.tar.gz)
# [sqlite](https://www.sqlite.org/index.html) | 3.6.10 | [github](https://github.com/mackyle/sqlite/tree/version-3.6.10) | 3.35.4 | [github](https://github.com/mackyle/sqlite/tree/version-3.35.4)
# [subversion](https://subversion.apache.org/) | 1.5.1 | [github](https://github.com/apache/subversion/tree/1.5.1) | 1.14.1 | [github](https://github.com/apache/subversion/tree/1.14.1)
# [sylpheed](https://sylpheed.sraoss.jp/en/) | 2.6.0 | [github](https://github.com/jan0sch/sylpheed/tree/release-2_6_0) | 3.6.0 | [github](https://github.com/jan0sch/sylpheed/tree/release-3_6_0)
# [tcl](https://core.tcl-lang.org/tcl/wiki?name=Index) | 8.5.7 | [github](https://github.com/tcltk/tcl/tree/core-8-5-7) | 8.6.11 | [github](https://github.com/tcltk/tcl/tree/core-8-6-11)
# [xfig](https://www.xfig.org/) | 3.2.5 | [sourceforge](https://sourceforge.net/p/mcj/xfig/ci/3.2.5/tree/) | 3.2.8a | [sourceforge](https://sourceforge.net/p/mcj/xfig/ci/3.2.8a/tree/)
# [xine-lib](http://xinehq.de/) | 1.1.16 | [sourceforge](https://sourceforge.net/p/xine/xine-lib/ci/1.1.16.2/tree/) | 1.1.20.1 | [sourceforge](https://sourceforge.net/p/xine/xine-lib/ci/1.1.20.1/tree/)
# [xterm](https://invisible-island.net/xterm/) | 2.4.3 | [github](https://github.com/ThomasDickey/xterm-snapshots/tree/xterm-243) | 3.1.7c | [github](https://github.com/ThomasDickey/xterm-snapshots/tree/xterm317c)
#
# This projects are extracted from Liebig (2011) paper. Others projects from this paper are not found.

# %% [markdown]
# ## Results
#
# After run cppstats on each project, we have the table:
#
# projectname|version|domain|#LOC|#AA|%disciplined
# --|--|--|--|--|--
# apache|2.2.11|Web server|137050|1486|85.46
# apache|2.4.46|Web server|199652|1707|86.88
# berkeley.db|18.1.40|database system|260938|3932|92.57
# berkeley.db|4.7.25|database system|184692|3159|92.28
# cherokee|0.99.11|Web server|52132|597|88.78
# cherokee|1.2.104|Web server|60010|651|89.86
# clamav|0.104|antivirus program|249329|2130|90.52
# clamav|0.94.2|antivirus program|77666|1002|85.23
# cpython|2.6.1|program interpreter|374304|8411|93.39
# cpython|3.9.3|program interpreter|505015|8633|92.73
# dia|0_96_1|diagramming software|139301|341|96.48
# dia|0_97_2|diagramming software|145595|391|95.65
# emacs|22.3|text editor|23308|459|95.64
# emacs|27.1.91|text editor|58137|2738|93.83
# freebsd|12.2.0|operating system|11482530|117468|91.99
# freebsd|7.1.0|operating system|5004762|63134|91.91
# gcc|10.2.0|compiler framework|3237149|22263|86.4
# gcc|4.3.3|compiler framework|1518746|12416|86.09
# ghostscript|8.62|postscript interpreter|526787|5450|91.08
# ghostscript|9.52|postscript interpreter|1288670|9563|90.04
# gimp|2_10_24|graphics editor|809194|1726|95.77
# gimp|2_6_4|graphics editor|619247|1126|95.03
# glibc|2.33|programming library|875382|10424|93.36
# glibc|2.9|programming library|746438|10705|85.6
# gnumeric|1_12_49|spreadsheet application|288182|469|93.6
# gnumeric|1_9_5|spreadsheet application|251343|1285|86.93
# gnuplot|4.2.5|plotting tool|76117|1850|86.92
# gnuplot|5.4.1|plotting tool|100274|1343|86.9
# irssi|0.8.13|IRC client|52533|152|88.16
# irssi|1.2.2|IRC client|60732|141|87.94
# libxml2|2.7.3|XML library|209324|9163|96.63
# libxml2|2.9.10|XML library|224488|9459|96.5
# lighttpd|1.4.22|Web server|36654|596|96.14
# lighttpd|1.4.59|Web server|82676|1490|92.35
# linux|2.6.28.7|operating system|6048447|41086|96.41
# linux|5.12.5|operating system|19909287|66138|96.91
# lynx|2.8.6|Web browser|117408|3591|83.79
# lynx|2.8.8|Web browser|126435|3754|84.15
# openldap|2_4_16|LDAP directory service|249719|2579|93.37
# openldap|2_4_58|LDAP directory service|284912|2903|92.87
# openvpn|2.1_rc1|seftrity application|57709|1479|89.93
# openvpn|2.5.1|seftrity application|89042|1666|93.04
# parrot|0_9_1|virtual machine|92204|1138|96.84
# parrot|2_9_1|virtual machine|107173|773|97.28
# php|5.2.8|program interpreter|561647|6774|91.48
# php|8.0.4RC1|program interpreter|800710|10353|92.36
# postgres|13_2|database system|859130|3980|87.09
# postgres|8_4_BETA2|database system|490460|2866|87.02
# privoxy|3.0.12|proxy server|6003|68|88.24
# privoxy|3.0.24|proxy server|29681|776|87.63
# sendmail|8.14.2|mail transfer agent|88369|2660|90.49
# sendmail|8.16.1|mail transfer agent|95655|3122|90.58
# sqlite|3.35.4|database system|255477|4134|93.83
# sqlite|3.6.10|database system|92096|1437|91.93
# subversion|1.14.1|revision control system|148339|484|65.29
# subversion|1.5.1|revision control system|25908|98|63.27
# sylpheed|2_6_0|e-mail client|98210|645|85.89
# sylpheed|3_6_0|e-mail client|114567|911|88.36
# tcl|8.5.7|program interpreter|24986|1532|97.39
# tcl|8.6.11|program interpreter|35909|876|90.3
# xfig|3.2.5|vector graphics editor|73363|358|85.75
# xfig|3.2.8a|vector graphics editor|74904|348|84.48
# xinelib|1.1.16.2|media library|467013|4081|88.75
# xinelib|1.1.20.1|media library|470247|4203|88.53
# xterm|2.4.3|terminal emulator|49626|1763|92.23
# xterm|3.1.7c|terminal emulator|67427|2194|93.62
#
# Where:
#
# - #LOC: Line of codes
# - #AA: All Annotations. Or ifdef blocks
# - %disciplined: disciplined blocks
#
# The projects with more than 3% or less than -3% of disciplined changes from version 0 to 1 are listed below:
#
# Project | Disciplined Diff
# --------|-----------------
# clamav  | +5.29%
# glibc | +7.76%
# gnumeric | +6.67%
# lighttpd | -3.79%
# openvpn | +3.11%
# tcl | -7.09%
#
# Where:
#
# - **Disciplined Diff**: increase/decrease of the disciplined code from version 0 to version 1.
#
# The 3% cut number is arbitrary. If higher, the smaller the number of results. The goal here is find *some* evidence that there are enough disciplined/undisciplined code to collect later.

# %% [markdown]
# ## Threat
#
# From version 0 to version 1, there is certainly unchange code. So, to investigate if there are changes to disciplined or undisciplined code, this immutable files is harmful for analysis, as it can change the results.

# %% [markdown]
# # Part 2: Remove duplicates

# %% [markdown]
# ## Idea
#
# Remove equal files in both versions. And files with no changes on #ifdef blocks. With this, we can remove the threat from Part 1.

# %% [markdown]
# ## Structure and Algorithms
#
# The cppstats have 2 phases: preparation and analysis.
#
# - Preparation: transform each file of each project to xml, and do some treatment.
# - Analysis: find ifdefs blocks and count disciplined/undisciplined code.
#
# After preparation and before analysis, we can remove equals files and files with equals ifdef blocks. With this, is possible to analyze only the changes between version 0 and 1.
#
# So, the operation between preparation and analysis we call *filter*. The filter operation do the following tasks:
#
# - Remove equal files
# - Remove Files with equal ifdef blocks. Not any block, but all blocks on each file.

# %% [markdown]
# ## Results
#
# After filter operation, the following projects are removed from the results:
#
# - ghostscript: no files are removed.
# - irssi: low number of disciplined (absolute) changes from one version to another
# - lynx: the version 0 have all data equals to 0 (zero).
# - openvpn: no files are removed.
# - privoxy: the version 0 and 1 have all data equals to 0 (zero).
# - sendmail: the version 0 have all data equals to 0 (zero).
# - subversion: low number of ifdef blocks in version 0
# - sylpheed: the version 0 have all data equals to 0 (zero).
# - xfig: no files are removed.
# - xinelib: low number of ifdef blocks in both versions.
#
# For the other projects, the filter operation have the result:
#
# project|total files (version 0)|total files (version 1)|total removed
# --|--|--|--
# apache|589|1875|212
# berkeley.db|1862|2801|14
# cherokee|354|1043|208
# clamav|635|6518|182
# cpython|1473|2661|318
# dia|648|1920|292
# emacs|1312|1738|111
# freebsd|50525|217550|8824
# gcc|79968|275368|2762
# gimp|3935|12565|1789
# glibc|16733|54383|3915
# gnumeric|1018|2152|428
# gnuplot|219|678|134
# libxml2|168|544|100
# lighttpd|203|577|95
# linux|65263|284603|9059
# openldap|1122|3017|353
# parrot|700|1294|187
# php|3302|7573|716
# postgres|2111|11077|1143
# sqlite|174|1379|133
# tcl|434|1462|118
# xterm|59|128|46
#
# The following table have the result after analysis operation:
#
# projectname|version|domain|#LOC|#AA|%disciplined
# --|--|--|--|--|--
# apache|2.2.11|Web server|35873|350|82
# apache|2.4.46|Web server|78287|387|86.3
# berkeley.db|18.1|Web server|252018|3823|92.68
# berkeley.db|4.7.25|Web server|178003|3077|92.46
# cherokee|0.99.11|database system|4383|19|89.47
# cherokee|1.2.104|database system|5926|37|100
# clamav|0.104|antivirus program|166726|1439|90.48
# clamav|0.94.2|antivirus program|17379|237|88.61
# cpython|2.6.1|program interpreter|155860|4643|96.58
# cpython|3.9.3|program interpreter|203773|4036|95
# dia|0.96.1|diagramming software|13937|46|95.65
# dia|0.97.2|diagramming software|17526|80|100
# emacs|22.3|text editor|8654|322|94.41
# emacs|27.1.91|text editor|42568|2583|93.57
# freebsd|12.2|operating system|7601435|70904|92.09
# freebsd|7.1|operating system|1632428|20155|91.67
# gcc|10.2.0|compiler framework|2117635|10729|88.39
# gcc|4.3.3|compiler framework|644729|4880|85.78
# gimp|2.10.24|graphics editor|247393|358|96.09
# gimp|2.6.4|graphics editor|119810|267|97.75
# glibc|2.33|programming library|230290|4093|93.43
# glibc|2.9|programming library|107781|2721|89.97
# gnumeric|1.12.49|spreadsheet application|49814|94|90.43
# gnumeric|1.9.5|spreadsheet application|59399|792|82.58
# gnuplot|4.2.5|plotting tool|3772|61|83.61
# gnuplot|5.4.1|plotting tool|10190|89|88.76
# libxml2|2.7.3|XML library|47647|1005|98.81
# libxml2|2.9.10|XML library|58701|1070|97.76
# lighttpd|1.4.22|Web server|3341|58|98.28
# lighttpd|1.4.59|Web server|42278|790|92.03
# linux|2.6.28.7|operating system|2969690|20011|96.39
# linux|5.12.5|operating system|16014484|40877|97.17
# openldap|2.4.16|LDAP directory service|9431|68|95.59
# openldap|2.4.58|LDAP directory service|28539|316|92.09
# parrot|0.9.1|virtual machine|28164|582|97.42
# parrot|2.9.1|virtual machine|45939|278|98.56
# php|5.2.8|program interpreter|192829|2640|90.08
# php|8.0.4.rc1|program interpreter|315432|4838|92.79
# postgres|13.2|database system|250686|1291|89.54
# postgres|8.4.beta2|database system|29494|199|92.46
# sqlite|3.35.4|database system|127642|1099|93.99
# sqlite|3.6.10|database system|3424|43|93.02
# tcl|8.5.7|program interpreter|10192|262|95.42
# tcl|8.6.11|program interpreter|24585|607|88.8
# xterm|2.4.3|terminal emulator|1729|99|94.95
# xterm|3.1.7c|terminal emulator|7780|70|100
#
# On general, there have been significant changes in the metric of disciplined code changes before and after filter operation:
#
# ![image.png](attachment:4153c0e5-daf1-4e98-b490-b495461eac18.png)
#
# And the following projects have more than +3% or less than -3% of disciplined changes from version 0 to 1:
#
# ![image.png](attachment:0a14ba36-bb8f-4f19-bc94-8bb9794252b2.png)
#
# As can be seen, more projects are candidates to have transformation of refactoring from version 0 to 1.
